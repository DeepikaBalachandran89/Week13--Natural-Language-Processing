# %%
import pandas as pd

# %%
df = pd.read_csv("chat.txt",delimiter=',', header=None, on_bad_lines='skip', encoding='utf8')

# %%
df
# Out:
#              0                                                  1  \
# 0     18/07/22   6:25 pm - Messages and calls are end-to-end e...
# 1     18/07/22        6:25 pm - ✌️Trio Tech Akshaya😇: Hi Ram Anna
# 2     18/07/22                         6:26 pm - Ram: Yes working
# 3     18/07/22   6:27 pm - ✌️Trio Tech Akshaya😇: This message ...
# 4     18/07/22      6:27 pm - ✌️Trio Tech Akshaya😇: Okay tks anna
# ...        ...                                                ...
# 2729  31/07/24                     1:52 pm - Ram: <Media omitted>
# 2730  31/07/24   1:52 pm - ✌️Trio Tech Akshaya😇: Thankkk youuu...
# 2731  01/08/24             7:08 pm - ✌️Trio Tech Akshaya😇: Annaaa
# 2732  01/08/24              7:08 pm - ✌️Trio Tech Akshaya😇: Doubt
# 2733  01/08/24   7:08 pm - ✌️Trio Tech Akshaya😇: Please call w...
#
#                                                       2  \
# 0                                     not even WhatsApp
# 1      is the instance working? This Akshaya from hc...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2729                                                NaN
# 2730                                                NaN
# 2731                                                NaN
# 2732                                                NaN
# 2733                                                NaN
#
#                                                     3
# 0      can read or listen to them. Tap to learn more.
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 2729                                              NaN
# 2730                                              NaN
# 2731                                              NaN
# 2732                                              NaN
# 2733                                              NaN
#
# [2734 rows x 4 columns]

# %%
df = df.drop(0)  #0 row deleted

# %%
df
# Out:
#              0                                                  1  \
# 1     18/07/22        6:25 pm - ✌️Trio Tech Akshaya😇: Hi Ram Anna
# 2     18/07/22                         6:26 pm - Ram: Yes working
# 3     18/07/22   6:27 pm - ✌️Trio Tech Akshaya😇: This message ...
# 4     18/07/22      6:27 pm - ✌️Trio Tech Akshaya😇: Okay tks anna
# 5     18/07/22        6:28 pm - Ram: You are from EBS background?
# ...        ...                                                ...
# 2729  31/07/24                     1:52 pm - Ram: <Media omitted>
# 2730  31/07/24   1:52 pm - ✌️Trio Tech Akshaya😇: Thankkk youuu...
# 2731  01/08/24             7:08 pm - ✌️Trio Tech Akshaya😇: Annaaa
# 2732  01/08/24              7:08 pm - ✌️Trio Tech Akshaya😇: Doubt
# 2733  01/08/24   7:08 pm - ✌️Trio Tech Akshaya😇: Please call w...
#
#                                                       2    3
# 1      is the instance working? This Akshaya from hc...  NaN
# 2                                                   NaN  NaN
# 3                                                   NaN  NaN
# 4                                                   NaN  NaN
# 5                                                   NaN  NaN
# ...                                                 ...  ...
# 2729                                                NaN  NaN
# 2730                                                NaN  NaN
# 2731                                                NaN  NaN
# 2732                                                NaN  NaN
# 2733                                                NaN  NaN
#
# [2733 rows x 4 columns]

# %%
df
# Out:
#              0                                                  1  \
# 1     18/07/22        6:25 pm - ✌️Trio Tech Akshaya😇: Hi Ram Anna
# 2     18/07/22                         6:26 pm - Ram: Yes working
# 3     18/07/22   6:27 pm - ✌️Trio Tech Akshaya😇: This message ...
# 4     18/07/22      6:27 pm - ✌️Trio Tech Akshaya😇: Okay tks anna
# 5     18/07/22        6:28 pm - Ram: You are from EBS background?
# ...        ...                                                ...
# 2729  31/07/24                     1:52 pm - Ram: <Media omitted>
# 2730  31/07/24   1:52 pm - ✌️Trio Tech Akshaya😇: Thankkk youuu...
# 2731  01/08/24             7:08 pm - ✌️Trio Tech Akshaya😇: Annaaa
# 2732  01/08/24              7:08 pm - ✌️Trio Tech Akshaya😇: Doubt
# 2733  01/08/24   7:08 pm - ✌️Trio Tech Akshaya😇: Please call w...
#
#                                                       2    3
# 1      is the instance working? This Akshaya from hc...  NaN
# 2                                                   NaN  NaN
# 3                                                   NaN  NaN
# 4                                                   NaN  NaN
# 5                                                   NaN  NaN
# ...                                                 ...  ...
# 2729                                                NaN  NaN
# 2730                                                NaN  NaN
# 2731                                                NaN  NaN
# 2732                                                NaN  NaN
# 2733                                                NaN  NaN
#
# [2733 rows x 4 columns]

# %%
df.drop(df.columns[2], axis=1, inplace=True)

# %%
df
# Out:
#              0                                                  1    3
# 1     18/07/22        6:25 pm - ✌️Trio Tech Akshaya😇: Hi Ram Anna  NaN
# 2     18/07/22                         6:26 pm - Ram: Yes working  NaN
# 3     18/07/22   6:27 pm - ✌️Trio Tech Akshaya😇: This message ...  NaN
# 4     18/07/22      6:27 pm - ✌️Trio Tech Akshaya😇: Okay tks anna  NaN
# 5     18/07/22        6:28 pm - Ram: You are from EBS background?  NaN
# ...        ...                                                ...  ...
# 2729  31/07/24                     1:52 pm - Ram: <Media omitted>  NaN
# 2730  31/07/24   1:52 pm - ✌️Trio Tech Akshaya😇: Thankkk youuu...  NaN
# 2731  01/08/24             7:08 pm - ✌️Trio Tech Akshaya😇: Annaaa  NaN
# 2732  01/08/24              7:08 pm - ✌️Trio Tech Akshaya😇: Doubt  NaN
# 2733  01/08/24   7:08 pm - ✌️Trio Tech Akshaya😇: Please call w...  NaN
#
# [2733 rows x 3 columns]

# %%
df.drop(df.columns[2], axis=1, inplace=True)

# %%
df
# Out:
#              0                                                  1
# 1     18/07/22        6:25 pm - ✌️Trio Tech Akshaya😇: Hi Ram Anna
# 2     18/07/22                         6:26 pm - Ram: Yes working
# 3     18/07/22   6:27 pm - ✌️Trio Tech Akshaya😇: This message ...
# 4     18/07/22      6:27 pm - ✌️Trio Tech Akshaya😇: Okay tks anna
# 5     18/07/22        6:28 pm - Ram: You are from EBS background?
# ...        ...                                                ...
# 2729  31/07/24                     1:52 pm - Ram: <Media omitted>
# 2730  31/07/24   1:52 pm - ✌️Trio Tech Akshaya😇: Thankkk youuu...
# 2731  01/08/24             7:08 pm - ✌️Trio Tech Akshaya😇: Annaaa
# 2732  01/08/24              7:08 pm - ✌️Trio Tech Akshaya😇: Doubt
# 2733  01/08/24   7:08 pm - ✌️Trio Tech Akshaya😇: Please call w...
#
# [2733 rows x 2 columns]

# %%
df.columns = ['Date', 'Chat']  #Column(0 1) changed to name

# %%
df
# Out:
#           Date                                               Chat
# 1     18/07/22        6:25 pm - ✌️Trio Tech Akshaya😇: Hi Ram Anna
# 2     18/07/22                         6:26 pm - Ram: Yes working
# 3     18/07/22   6:27 pm - ✌️Trio Tech Akshaya😇: This message ...
# 4     18/07/22      6:27 pm - ✌️Trio Tech Akshaya😇: Okay tks anna
# 5     18/07/22        6:28 pm - Ram: You are from EBS background?
# ...        ...                                                ...
# 2729  31/07/24                     1:52 pm - Ram: <Media omitted>
# 2730  31/07/24   1:52 pm - ✌️Trio Tech Akshaya😇: Thankkk youuu...
# 2731  01/08/24             7:08 pm - ✌️Trio Tech Akshaya😇: Annaaa
# 2732  01/08/24              7:08 pm - ✌️Trio Tech Akshaya😇: Doubt
# 2733  01/08/24   7:08 pm - ✌️Trio Tech Akshaya😇: Please call w...
#
# [2733 rows x 2 columns]

# %%
Message = df["Chat"].str.split("-",n=1,expand=True)

# %%
Message
# Out:
#               0                                                  1
# 1      6:25 pm                   ✌️Trio Tech Akshaya😇: Hi Ram Anna
# 2      6:26 pm                                    Ram: Yes working
# 3      6:27 pm      ✌️Trio Tech Akshaya😇: This message was deleted
# 4      6:27 pm                 ✌️Trio Tech Akshaya😇: Okay tks anna
# 5      6:28 pm                   Ram: You are from EBS background?
# ...         ...                                                ...
# 2729   1:52 pm                                Ram: <Media omitted>
# 2730   1:52 pm     ✌️Trio Tech Akshaya😇: Thankkk youuu annaaathe🥂🥂
# 2731   7:08 pm                        ✌️Trio Tech Akshaya😇: Annaaa
# 2732   7:08 pm                         ✌️Trio Tech Akshaya😇: Doubt
# 2733   7:08 pm    ✌️Trio Tech Akshaya😇: Please call when you ar...
#
# [2733 rows x 2 columns]

# %%
df["Time"] = Message[0]

# %%
df
# Out:
#           Date                                               Chat       Time
# 1     18/07/22        6:25 pm - ✌️Trio Tech Akshaya😇: Hi Ram Anna   6:25 pm
# 2     18/07/22                         6:26 pm - Ram: Yes working   6:26 pm
# 3     18/07/22   6:27 pm - ✌️Trio Tech Akshaya😇: This message ...   6:27 pm
# 4     18/07/22      6:27 pm - ✌️Trio Tech Akshaya😇: Okay tks anna   6:27 pm
# 5     18/07/22        6:28 pm - Ram: You are from EBS background?   6:28 pm
# ...        ...                                                ...        ...
# 2729  31/07/24                     1:52 pm - Ram: <Media omitted>   1:52 pm
# 2730  31/07/24   1:52 pm - ✌️Trio Tech Akshaya😇: Thankkk youuu...   1:52 pm
# 2731  01/08/24             7:08 pm - ✌️Trio Tech Akshaya😇: Annaaa   7:08 pm
# 2732  01/08/24              7:08 pm - ✌️Trio Tech Akshaya😇: Doubt   7:08 pm
# 2733  01/08/24   7:08 pm - ✌️Trio Tech Akshaya😇: Please call w...   7:08 pm
#
# [2733 rows x 3 columns]

# %%
Message1 = Message[1].str.split(":",n=1,expand=True)

# %%
Message1
# Out:
#                           0                                 1
# 1      ✌️Trio Tech Akshaya😇                       Hi Ram Anna
# 2                       Ram                       Yes working
# 3      ✌️Trio Tech Akshaya😇          This message was deleted
# 4      ✌️Trio Tech Akshaya😇                     Okay tks anna
# 5                       Ram      You are from EBS background?
# ...                     ...                               ...
# 2729                    Ram                   <Media omitted>
# 2730   ✌️Trio Tech Akshaya😇         Thankkk youuu annaaathe🥂🥂
# 2731   ✌️Trio Tech Akshaya😇                            Annaaa
# 2732   ✌️Trio Tech Akshaya😇                             Doubt
# 2733   ✌️Trio Tech Akshaya😇   Please call when you are free??
#
# [2733 rows x 2 columns]

# %%
#Message1 0column name nu change and df data oda joined
df["Name"] = Message1[0]
df["Chat"] = Message1[1]

# %%
df
# Out:
#           Date                              Chat       Time  \
# 1     18/07/22                       Hi Ram Anna   6:25 pm
# 2     18/07/22                       Yes working   6:26 pm
# 3     18/07/22          This message was deleted   6:27 pm
# 4     18/07/22                     Okay tks anna   6:27 pm
# 5     18/07/22      You are from EBS background?   6:28 pm
# ...        ...                               ...        ...
# 2729  31/07/24                   <Media omitted>   1:52 pm
# 2730  31/07/24         Thankkk youuu annaaathe🥂🥂   1:52 pm
# 2731  01/08/24                            Annaaa   7:08 pm
# 2732  01/08/24                             Doubt   7:08 pm
# 2733  01/08/24   Please call when you are free??   7:08 pm
#
#                        Name
# 1      ✌️Trio Tech Akshaya😇
# 2                       Ram
# 3      ✌️Trio Tech Akshaya😇
# 4      ✌️Trio Tech Akshaya😇
# 5                       Ram
# ...                     ...
# 2729                    Ram
# 2730   ✌️Trio Tech Akshaya😇
# 2731   ✌️Trio Tech Akshaya😇
# 2732   ✌️Trio Tech Akshaya😇
# 2733   ✌️Trio Tech Akshaya😇
#
# [2733 rows x 4 columns]

# %%
#column ah rearrange 
df=df[["Date", "Time", "Name", "Chat"]]

# %%
df
# Out:
#           Date       Time                   Name  \
# 1     18/07/22   6:25 pm    ✌️Trio Tech Akshaya😇
# 2     18/07/22   6:26 pm                     Ram
# 3     18/07/22   6:27 pm    ✌️Trio Tech Akshaya😇
# 4     18/07/22   6:27 pm    ✌️Trio Tech Akshaya😇
# 5     18/07/22   6:28 pm                     Ram
# ...        ...        ...                    ...
# 2729  31/07/24   1:52 pm                     Ram
# 2730  31/07/24   1:52 pm    ✌️Trio Tech Akshaya😇
# 2731  01/08/24   7:08 pm    ✌️Trio Tech Akshaya😇
# 2732  01/08/24   7:08 pm    ✌️Trio Tech Akshaya😇
# 2733  01/08/24   7:08 pm    ✌️Trio Tech Akshaya😇
#
#                                   Chat
# 1                          Hi Ram Anna
# 2                          Yes working
# 3             This message was deleted
# 4                        Okay tks anna
# 5         You are from EBS background?
# ...                                ...
# 2729                   <Media omitted>
# 2730         Thankkk youuu annaaathe🥂🥂
# 2731                            Annaaa
# 2732                             Doubt
# 2733   Please call when you are free??
#
# [2733 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2733 entries, 1 to 2733
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2733 non-null   object
#  1   Time    2724 non-null   object
#  2   Name    2723 non-null   object
#  3   Chat    2722 non-null   object
# dtypes: object(4)
# memory usage: 85.5+ KB

# %%
import matplotlib.pyplot as plt

message_counts = df.head(100).groupby(['Date', 'Name']).size().unstack(fill_value=0)

# Create a bar chart
message_counts.plot(kind='bar', figsize=(10, 6), color=['blue', 'orange'])

# Add titles and labels
plt.title('Date Wise Message Count')
plt.xlabel('Date')
plt.ylabel('Count')
#plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend(title='Name')   # Add a legend for users
#plt.tight_layout()  # Adjust layout to prevent clipping
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\envs\aiml\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9996 (\N{VICTORY HAND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Lenovo\anaconda3\envs\aiml\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 65039 (\N{VARIATION SELECTOR-16}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Lenovo\anaconda3\envs\aiml\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128519 (\N{SMILING FACE WITH HALO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
print("Flirt Encounters:")
message_counts = df['Name'].value_counts()
most_talkative_user = message_counts.idxmax()  # Gets the user name
least_talkative_user = message_counts.idxmin()
print(f"Talkative: {most_talkative_user}")
print(f"Less Talkative: {least_talkative_user}")
# Out:
# Flirt Encounters:
# Talkative:  ✌️Trio Tech Akshaya😇
# Less Talkative:  ✌️Trio Tech Akshaya😇 pinned a message

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize

print("Flirt Encounters:")
message_counts = df['Name'].value_counts()
most_talkative_user = message_counts.idxmax()  # Gets the user name
least_talkative_user = message_counts.idxmin()
print(f"Talkative: {most_talkative_user}")
print(f"Less Talkative: {least_talkative_user}")

nltk.download('punkt')
flirt_keywords = ['hey', 'great', 'thinking about you', 'sweet', '😉', 
                  'love', 'beautiful', 'cute', 'miss you', 'hugs', 
                  'kisses', 'us', 'coffee', 'amazing']
def is_flirtatious(message):
    if pd.isna(message):  # Check for None or NaN values
        return False
    tokens = word_tokenize(message.lower())
    return any(keyword in tokens for keyword in flirt_keywords)

# Apply the flirt detection function using .loc
df.loc[:, 'Flirtatious'] = df['Chat'].apply(is_flirtatious)

# Calculate total messages
total_messages = len(df)

# Calculate flirtatious messages
flirtatious_messages = df['Flirtatious'].sum()

# Calculate flirt percentage
flirt_percentage = (flirtatious_messages / total_messages) * 100

# Display the results
#print(f"Total Messages: {total_messages}")
#print(f"Flirtatious Messages: {flirtatious_messages}")
print(f"Flirt Percentage: {flirt_percentage:.2f}%")
# Out:
# Flirt Encounters:
# Talkative:  ✌️Trio Tech Akshaya😇
# Less Talkative:  ✌️Trio Tech Akshaya😇 pinned a message
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Flirt Percentage: 0.95%
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\3632201607.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'Flirtatious'] = df['Chat'].apply(is_flirtatious)

# %%
def is_flirtatious(message):
    if pd.isna(message):  # Check for None or NaN values
        return False
    tokens = word_tokenize(message.lower())
    return any(keyword in tokens for keyword in flirt_keywords)

# Apply the flirt detection function
df['Flirtatious'] = df['Chat'].apply(is_flirtatious)

# Calculate total messages and flirtatious messages by user
flirt_percentage_by_user = df.groupby('Name').agg(
    Total_Messages=('Chat', 'count'),
    Flirtatious_Messages=('Flirtatious', 'sum')
)

# Calculate flirt percentage
flirt_percentage_by_user['Flirt_Percentage'] = (
    flirt_percentage_by_user['Flirtatious_Messages'] / flirt_percentage_by_user['Total_Messages'] * 100
).fillna(0)  # Fill NaN with 0 for users with no messages
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\3876684881.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Flirtatious'] = df['Chat'].apply(is_flirtatious)

# %%
# Display only the flirt percentage values
flirt_percentage_values = flirt_percentage_by_user['Flirt_Percentage']
print(flirt_percentage_values)
# Out:
# Name
# Ram                                      0.442968
# ✌️Trio Tech Akshaya😇                     1.209456
# ✌️Trio Tech Akshaya😇 pinned a message    0.000000
# Name: Flirt_Percentage, dtype: float64

# %% [markdown]
# #### TIME ENCOUNTERS MUST CONVERT 'Date' column is converted to datetime format.

# %%
date_counts = df['Date'].value_counts()

# %%
date_counts
# Out:
# Date
# 15/02/23                            75
# 05/02/23                            57
# 26/08/22                            57
# 05/09/22                            51
# 12/09/22                            50
#                                     ..
# 21/08/22                             1
# 07/03/24                             1
# http://bz.dhunt.in/TiBwO             1
# By Wish Zone Tamil via Dailyhunt     1
# 01/12/23                             1
# Name: count, Length: 236, dtype: int64

# %%
most_active_date = date_counts.idxmax()

# %%
most_active_date
# Out:
# '15/02/23'

# %%
print(f"The most active date is: {most_active_date}")
# Out:
# The most active date is: 15/02/23

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%y', dayfirst=True, errors='coerce')
#errors='coerce': Invalid parsing will be set as NaN.
# Check for any invalid dates
if pd.api.types.is_datetime64_any_dtype(df['Date']):# datetime irundha dhan week day display hagum(upper line also need)
    print(f"Time Encounters")
    print(f"Most Active Date: {most_active_date}")
    # Extract the day of the week and create a new column
    df['Day_of_Week'] = df['Date'].dt.day_name()
    date_counts = df['Day_of_Week'].value_counts()
    # Get the most active day
    most_active_day = date_counts.idxmax()
    # Display the results
    print(f"Most Active Day: {most_active_day}")
# Out:
# Time Encounters
# Most Active Date: 15/02/23
# Most Active Day: Friday
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\3042497634.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%y', dayfirst=True, errors='coerce')
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\3042497634.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Day_of_Week'] = df['Date'].dt.day_name()

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%y', dayfirst=True, errors='coerce')
#errors='coerce': Invalid parsing will be set as NaN.
# Check for any invalid dates
if pd.api.types.is_datetime64_any_dtype(df['Date']):# datetime irundha dhan week day display hagum(upper line also need)
    print(f"Time Encounters")
    print(f"Most Active Date: {most_active_date}")
    # Extract the day of the week and create a new column
    df['Day_of_Week'] = df['Date'].dt.day_name()
    date_counts = df['Day_of_Week'].value_counts()
    # Get the most active day
    most_active_day = date_counts.idxmax()
    # Display the results
    print(f"Most Active Day: {most_active_day}")

# Convert 'Date' column to datetime format with error handling
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%y', dayfirst=True, errors='coerce')

# Convert 'Time' column to datetime format with error handling
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M', errors='coerce')


# Combine 'Date' and 'Time' into a single datetime column
df['DateTime'] = df['Date'].combine_first(df['Time'])

# Extract the hour from the combined datetime
df['Hour'] = df['DateTime'].dt.hour

# Count the number of messages per hour
active_hour_counts = df['Hour'].value_counts().sort_index()

# Get the most active hour
if not active_hour_counts.empty:
    most_active_hour = active_hour_counts.idxmax()
    most_active_count = active_hour_counts.max()
    
    # Print the result
    print(f"The most active hour is: {most_active_hour}:00")
else:
    print("There are no messages in the DataFrame or all hours have NaT values.")
    
# Group by date and count the number of messages
messages_per_day = df.groupby(df['Date'].dt.date).size()

# Calculate the average number of messages per day
average_messages_per_day = messages_per_day.mean()

# Print the result
print(f"The average number of messages per day is: {average_messages_per_day:.2f}")
# Out:
# Time Encounters
# Most Active Date: 15/02/23
# Most Active Day: Friday
# The most active hour is: 0.0:00
# The average number of messages per day is: 12.05
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\389610762.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%y', dayfirst=True, errors='coerce')
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\389610762.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Day_of_Week'] = df['Date'].dt.day_name()
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\389610762.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%y', dayfirst=True, errors='coerce')
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\389610762.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Time'] = pd.to_datetime(df['Time'], format='%H:%M', errors='coerce')
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\389610762.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DateTime'] = df['Date'].combine_first(df['Time'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\389610762.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Hour'] = df['DateTime'].dt.hour

# %% [markdown]
# #### MEDIA ENCOUNTERS  'Date' column is converted to datetime format.

# %%
print(f"Media Encounters")

# Define criteria for media messages
media_keywords = ['Media omitted']
# Count media messages
media_count = df[df['Chat'].str.contains('|'.join(media_keywords), na=False)].shape[0]
#na=False: This argument ensures that any NaN values in the 'Chat' column are treated as False, meaning they won't be counted as matches.
# Print the result
print(f"Media Count: {media_count}")

# Define criteria for deleted messages
deleted_keywords = ['deleted', 'This message was deleted', 'Message deleted']
# Count deleted messages
deleted_count = df[df['Chat'].str.contains('|'.join(deleted_keywords), case=False, na=False)].shape[0]
# Print the result
print(f"Deleted Message Count: {deleted_count}")

# Define criteria for missed voice calls
missed_call_keywords = ['Missed call', 'Missed voice call']
# Count missed voice calls
missed_call_count = df[df['Chat'].str.contains('|'.join(missed_call_keywords), case=False, na=False)].shape[0]
# Print the result
print(f"Missed Voice Call Count: {missed_call_count}")

# Define criteria for missed voice calls
missed_call_keywords = ['Missed call', 'Missed video call']
# Count missed voice calls
missed_call_count = df[df['Chat'].str.contains('|'.join(missed_call_keywords), case=False, na=False)].shape[0]
# Print the result
print(f"Missed Video Call Count: {missed_call_count}")
# Out:
# Media Encounters
# Media Count: 62
# Deleted Message Count: 12
# Missed Voice Call Count: 5
# Missed Video Call Count: 1

# %% [markdown]
# #### PERFORM SENTIMENT ANALYSIS

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
dataset=df

# %%
dataset
# Out:
#           Date       Time                   Name  \
# 1     18/07/22   6:25 pm    ✌️Trio Tech Akshaya😇
# 2     18/07/22   6:26 pm                     Ram
# 3     18/07/22   6:27 pm    ✌️Trio Tech Akshaya😇
# 4     18/07/22   6:27 pm    ✌️Trio Tech Akshaya😇
# 5     18/07/22   6:28 pm                     Ram
# ...        ...        ...                    ...
# 2729  31/07/24   1:52 pm                     Ram
# 2730  31/07/24   1:52 pm    ✌️Trio Tech Akshaya😇
# 2731  01/08/24   7:08 pm    ✌️Trio Tech Akshaya😇
# 2732  01/08/24   7:08 pm    ✌️Trio Tech Akshaya😇
# 2733  01/08/24   7:08 pm    ✌️Trio Tech Akshaya😇
#
#                                   Chat
# 1                          Hi Ram Anna
# 2                          Yes working
# 3             This message was deleted
# 4                        Okay tks anna
# 5         You are from EBS background?
# ...                                ...
# 2729                   <Media omitted>
# 2730         Thankkk youuu annaaathe🥂🥂
# 2731                            Annaaa
# 2732                             Doubt
# 2733   Please call when you are free??
#
# [2733 rows x 4 columns]

# %%
dataset.dropna(inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\2639109627.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.dropna(inplace=True)

# %%
sid = SentimentIntensityAnalyzer()

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
senti=sid.polarity_scores(dataset['Chat'][4])

# %%
senti
# Out:
# {'neg': 0.0, 'neu': 0.513, 'pos': 0.487, 'compound': 0.2263}

# %%
 def sentimentalAnalysis(data,columnname):
        
        #downloading vader_lexicon for the process
        import matplotlib.pyplot as plt
        import seaborn as sns
        "Importing Necessary Packeage"
        from nltk.sentiment.vader import SentimentIntensityAnalyzer
        sid = SentimentIntensityAnalyzer()
        
        "Deleting null pr empty value"
        data.dropna(inplace=True)
        
        "Checking for a comment"
        #sid.polarity_scores(data[columnname][93])
        
        "Creating respective columns"
        
        data['scores'] = data[columnname].apply(lambda commentText: sid.polarity_scores(commentText))
        data['compound']  = data['scores'].apply(lambda score_dict: score_dict['compound'])
        data['Negtive']  = data['scores'].apply(lambda score_dict: score_dict['neg'])
        data['Postive']  = data['scores'].apply(lambda score_dict: score_dict['pos'])
        data['Neutral']  = data['scores'].apply(lambda score_dict: score_dict['neu'])
        
        "Creating final pos or neg using compound score"
        data['comp_score'] = data['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')
        plt.clf()
        #comp=sns.countplot(x = 'comp_score', hue = 'Name', data = data, palette = 'magma')
        #comp.figure.savefig("date_charts.png")
        "Checking how many pos and neg"
        posneg=pd.DataFrame(data['comp_score'].value_counts())
        return posneg,data

# %%
pos,data_Senti=sentimentalAnalysis(dataset,columnname='Chat') #already inbuily function just give columnname
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\2009568695.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\2009568695.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['scores'] = data[columnname].apply(lambda commentText: sid.polarity_scores(commentText))
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\2009568695.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['compound']  = data['scores'].apply(lambda score_dict: score_dict['compound'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\2009568695.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Negtive']  = data['scores'].apply(lambda score_dict: score_dict['neg'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\2009568695.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Postive']  = data['scores'].apply(lambda score_dict: score_dict['pos'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\2009568695.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Neutral']  = data['scores'].apply(lambda score_dict: score_dict['neu'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\2009568695.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['comp_score'] = data['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')

# %%
data_Senti
# Out:
#           Date       Time                   Name  \
# 1     18/07/22   6:25 pm    ✌️Trio Tech Akshaya😇
# 2     18/07/22   6:26 pm                     Ram
# 3     18/07/22   6:27 pm    ✌️Trio Tech Akshaya😇
# 4     18/07/22   6:27 pm    ✌️Trio Tech Akshaya😇
# 5     18/07/22   6:28 pm                     Ram
# ...        ...        ...                    ...
# 2729  31/07/24   1:52 pm                     Ram
# 2730  31/07/24   1:52 pm    ✌️Trio Tech Akshaya😇
# 2731  01/08/24   7:08 pm    ✌️Trio Tech Akshaya😇
# 2732  01/08/24   7:08 pm    ✌️Trio Tech Akshaya😇
# 2733  01/08/24   7:08 pm    ✌️Trio Tech Akshaya😇
#
#                                   Chat  \
# 1                          Hi Ram Anna
# 2                          Yes working
# 3             This message was deleted
# 4                        Okay tks anna
# 5         You are from EBS background?
# ...                                ...
# 2729                   <Media omitted>
# 2730         Thankkk youuu annaaathe🥂🥂
# 2731                            Annaaa
# 2732                             Doubt
# 2733   Please call when you are free??
#
#                                                  scores  compound  Negtive  \
# 1     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 2     {'neg': 0.0, 'neu': 0.27, 'pos': 0.73, 'compou...    0.4019      0.0
# 3     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 4     {'neg': 0.0, 'neu': 0.513, 'pos': 0.487, 'comp...    0.2263      0.0
# 5     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# ...                                                 ...       ...      ...
# 2729  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 2730  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 2731  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 2732  {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...   -0.3612      1.0
# 2733  {'neg': 0.0, 'neu': 0.402, 'pos': 0.598, 'comp...    0.7149      0.0
#
#       Postive  Neutral comp_score
# 1       0.000    1.000        pos
# 2       0.730    0.270        pos
# 3       0.000    1.000        pos
# 4       0.487    0.513        pos
# 5       0.000    1.000        pos
# ...       ...      ...        ...
# 2729    0.000    1.000        pos
# 2730    0.000    1.000        pos
# 2731    0.000    1.000        pos
# 2732    0.000    0.000        neg
# 2733    0.598    0.402        pos
#
# [2722 rows x 10 columns]

# %%
pos
# Out:
#             count
# comp_score
# pos          2559
# neg           163

# %%
selected_columns = df[['Name', 'comp_score']]

# %%
selected_columns
# Out:
#                        Name comp_score
# 1      ✌️Trio Tech Akshaya😇        pos
# 2                       Ram        pos
# 3      ✌️Trio Tech Akshaya😇        pos
# 4      ✌️Trio Tech Akshaya😇        pos
# 5                       Ram        pos
# ...                     ...        ...
# 2729                    Ram        pos
# 2730   ✌️Trio Tech Akshaya😇        pos
# 2731   ✌️Trio Tech Akshaya😇        pos
# 2732   ✌️Trio Tech Akshaya😇        neg
# 2733   ✌️Trio Tech Akshaya😇        pos
#
# [2722 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample data creation


# Create a DataFrame
dff = selected_columns

# Count the occurrences of each sentiment score for each name
count_df = dff.groupby(['Name', 'comp_score']).size().reset_index(name='count')

# Set the style for seaborn
sns.set(style="whitegrid")

# Create a bar plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='comp_score', y='count', hue='Name', data=count_df, palette='bright')

# Add titles and labels
plt.title('Sentiment Analysis')
plt.xlabel('comp_score')
plt.ylabel('Count')

# Include a legend with title for sentiment scores
plt.legend(title='Name')

# Show the plot
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to make room for rotated labels
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\3767500837.py:31: UserWarning: Glyph 9996 (\N{VICTORY HAND}) missing from current font.
#   plt.tight_layout()  # Adjust layout to make room for rotated labels
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\3767500837.py:31: UserWarning: Glyph 65039 (\N{VARIATION SELECTOR-16}) missing from current font.
#   plt.tight_layout()  # Adjust layout to make room for rotated labels
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\3767500837.py:31: UserWarning: Glyph 128519 (\N{SMILING FACE WITH HALO}) missing from current font.
#   plt.tight_layout()  # Adjust layout to make room for rotated labels
# C:\Users\Lenovo\anaconda3\envs\aiml\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9996 (\N{VICTORY HAND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Lenovo\anaconda3\envs\aiml\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 65039 (\N{VARIATION SELECTOR-16}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Lenovo\anaconda3\envs\aiml\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128519 (\N{SMILING FACE WITH HALO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### TOPIC MODELLING

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
missing_count = df['Chat'].isnull().sum()
print(f"Missing values in 'Chat' column: {missing_count}")

# Display rows with missing values
rows_with_missing = df[df['Chat'].isnull()]
print(rows_with_missing)
# Out:
# Missing values in 'Chat' column: 0
# Empty DataFrame
# Columns: [Date, Time, Name, Chat, scores, compound, Negtive, Postive, Neutral, comp_score]
# Index: []

# %%
df['Chat'].fillna('No message', inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\913838890.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Chat'].fillna('No message', inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5328\913838890.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Chat'].fillna('No message', inplace=True)

# %%
tfidf=TfidfVectorizer(max_df=0.95,min_df=2,stop_words='english')      # vector created  TEXT TO NUMBER
dtm=tfidf.fit_transform(df["Chat"])

# %%
from sklearn.decomposition import NMF               #NON MATRIX FACTORIZATION ALGM
nmf_model=NMF(n_components=5,random_state=42)    #5 topics need
nmf_model.fit(dtm)
# Out:
# NMF(n_components=5, random_state=42)

# %%
# Retrieve the top words for each topic
for index, topic in enumerate(nmf_model.components_):
    # Use get_feature_names_out() to retrieve feature names
    results = [tfidf.get_feature_names_out()[i] for i in topic.argsort()[-10:]]
    print(f"{index + 0}: {[', '.join(results)]}")
# Out:
# 0: ['tomorrow, uh, yeah, super, joined, hi, hello, sure, yes, anna']
# 1: ['problem, ca, hmmm, mins, fine, connect, va, oh, sure, okay']
# 2: ['best, showing, amma, ann, ana, free, sorry, annaaa, akshaya, hi']
# 3: ['busy, jus, abba, ah, oh, msg, come, hahaha, sure, ok']
# 4: ['10, shall, 30, tmrw, tomorrow, joined, yes, connect, omitted, media']

# %% [markdown]
# #### WORD CLOUD

# %%
dataset=df
from wordcloud import WordCloud
from nltk.corpus import stopwords
import nltk
import matplotlib.pyplot as plt
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Sample DataFrame creation with chat messages
dataset = df

# Combine all chat messages into a single string
text = ' '.join(dataset['Chat'].dropna())

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Turn off the axis
plt.title('Word Cloud from Chat Messages')
plt.show()
